# %% [markdown]
# # Wizualizacja i przetwarzanie danych - web scraping z `Scrapy`
# ###### dr inż. Marcin Lawnik

# %% [markdown]
# ## `Scrapy`

# %% [markdown]
# > An open source and collaborative framework for extracting the data you need from websites. In a fast, simple, yet extensible way.

# %% [markdown]
# [https://scrapy.org/](https://scrapy.org/)

# %% [markdown]
# **Instalacja**
# ```
# conda install -c conda-forge scrapy
# ```

# %% [markdown]
# **Dokumentacja**
#
# [https://doc.scrapy.org/en/latest/index.html](https://doc.scrapy.org/en/latest/index.html)

# %% [markdown]
# **Tutorial**
#
# [https://doc.scrapy.org/en/latest/intro/tutorial.html](https://doc.scrapy.org/en/latest/intro/tutorial.html)

# %% [markdown]
# **Scrapy w jupyterze**
#
# [https://docs.scrapy.org/en/latest/topics/practices.html#run-scrapy-from-a-script](https://docs.scrapy.org/en/latest/topics/practices.html#run-scrapy-from-a-script)
